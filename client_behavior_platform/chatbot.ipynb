# %%
folder_path="/Users/hadilsahraoui/Downloads/spark_delta_hive_metastore-main 2/client_behavior_platform/data"

# %%
# Out:
# Exécution d'une analyse exemple...
# Envoi de la requête au modèle Qwen...
# Réponse brute reçue du modèle:
# ```json
# {
#     "intent": "Analyse des clients à haut risque de churn pour février 2025",
#     "tables": ["client_info_02_2025.csv", "segmentation_mois_02_2024.csv"],
#     "code": "'''python\n# Filtre clients bas d'engagement et activité récente faible\nthreshold_engagement = client_info['engagement_score'].quantile(0.1)\nthreshold_activity = client_info['frequence_utilisation_mensuelle'].quantile(0.95)\nchurn_risk_clients = client_info[(client_info['engagement_score'] < threshold_engagement) & (client_info['frequence_utilisation_mensuelle'] > threshold_activity)]\n'''",
#     "visualization": {
#         "type": "bar/pie",
#         "purpose": "Comparaison des caractéristiques de clients à risque avec la base globale"
#     },
#     "warnings": ["Données limitées à février 2025"]
# }
# ```
#
# ...
# JSON extrait avec succès après nettoyage!
# ...
